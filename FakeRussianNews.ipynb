# %% [markdown]
# <div align='center'>
#     <img src='https://ieee-dataport.org/sites/default/files/WhatsApp%20Image%202020-08-17%20at%2010.32.28%20PM_1.jpeg'><br>
#     Решение соревнования с Kaggle
#     <a href='https://www.kaggle.com/datasets/morfifinka/fake-real-news-ru'>https://www.kaggle.com/datasets/morfifinka/fake-real-news-ru</a>
# </div>

# %% [markdown]
# # 1.1 Загрузка библиотек и парсинг данных

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import nltk
from nltk.corpus import stopwords
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import warnings
# Отключаю предупреждения
warnings.filterwarnings('ignore')

# %%
# Загрузка данных
test_stances = pd.read_csv("test_stances_unlebeledb.csv", index_col='Unnamed: 0')
test_bodies = pd.read_csv("test_bodies.csv", index_col='Unnamed: 0')
train_bodies = pd.read_csv("train_bodies.csv", index_col='Unnamed: 0')
train_stances = pd.read_csv("train_stances.csv", index_col='Unnamed: 0')

# %%
# Объединения двух csv-файлов тренирвочной выборки в один файл
count=0
for i in tqdm(range(train_stances.shape[0])):
    for j in range(train_bodies.shape[0]):
        if train_bodies.loc[j,'Body ID']==train_stances.loc[i,'Body ID']:
            train_stances.loc[i,'articleBody'] = train_bodies.loc[j,'articleBody']
            train_stances.loc[i,'articleBody1'] = train_bodies.loc[j,'articleBody1']
            train_stances.loc[i,'articleBody2'] = train_bodies.loc[j,'articleBody2']
    train_stances.to_csv('data_combined.csv',index=False)
# Out:
#   0%|          | 0/4408 [00:00<?, ?it/s]

# %%
data = pd.read_csv('data_combined.csv') # Запишем новые данные в файл
data # Посмотрим на данные
# Out:
#       Body ID                                           Headline    Stance  \
# 0           1  ['российский', 'бюджет', 'марте', 'недополучил...     agree
# 1           2  ['банк', 'россии', 'решил', 'снизить', 'ключев...     agree
# 2           3  ['мыс', 'идокопас', 'нато', 'назвали', 'первую...  disagree
# 3           4  ['украине', 'прошли', 'празднования', '300', '...  disagree
# 4           5  ['минобороны', 'рф', 'заявило', 'ударах', 'рак...     agree
# ...       ...                                                ...       ...
# 4403     4404  ['чиновница', 'призвавшая', '«найти', 'покарат...  disagree
# 4404     4405  ['«включим', 'программу', 'киселёва', 'покажем...  disagree
# 4405     4406  ['китайские', 'власти', 'могут', 'казнить', 'з...  disagree
# 4406     4407  ['луганской', 'области', 'переполнены', 'морги...     agree
# 4407     4408  ['забывшему', 'удостоверение', 'депутату', 'го...  disagree
#
#                                               Headline1  \
# 0     российский бюджет в марте недополучил более 30...
# 1     банк россии решил снизить ключевую ставку с 20...
# 2     мыс идокопас  в нато назвали первую цель для н...
# 3     на украине прошли празднования 300 летия побед...
# 4     минобороны рф заявило об ударах ракетами «кали...
# ...                                                 ...
# 4403  чиновница призвавшая «найти и покарать предате...
# 4404  «включим программу киселёва и покажем телевизо...
# 4405  китайские власти могут казнить задержанного по...
# 4406  в луганской области переполнены морги  хранить...
# 4407  забывшему удостоверение депутату госдумы пришл...
#
#                                               Headline2  \
# 0     российский бюджет март недополучать миллиард р...
# 1            банк россия решать снижать ключевой ставка
# 2     мыс идокопас нато называть первый цель начало ...
# 3     украина проходить празднование летие победа ка...
# 4     минобороны заявлять удар ракета калибр запорож...
# ...                                                 ...
# 4403  чиновница призывать находить покарать предател...
# 4404  включать программа киселев показывать телевизо...
# 4405  китайский власть мочь казнить задержанный подо...
# 4406  луганский область переполнять морг хранить тел...
# 4407  забывать удостоверение депутат госдума приходи...
#
#                                             articleBody  \
# 0     Разница между ожидаемыми по итогам марта нефте...
# 1     Совет директоров Банка России решил снизить кл...
# 2     В НАТО составили наступательный план действий ...
# 3     Президент Владимир Зеленский принял в Полтаве ...
# 4     Минобороны России объявило, что ракетами больш...
# ...                                                 ...
# 4403  Заместитель министра просвещения Ирина Карепин...
# 4404  Глава штабов Навального Леонид Волков призвал ...
# 4405  Один из менеджеров стройки космодрома Восточны...
# 4406  Морги Луганской области переполнены телами пог...
# 4407  В Москве западные журналисты засняли, как один...
#
#                                            articleBody1  \
# 0     разница ожидаемыми итогам марта нефтегазовыми ...
# 1     совет директоров банка россии решил снизить кл...
# 2     нато составили наступательный план действий за...
# 3     президент владимир зеленский принял полтаве па...
# 4     минобороны россии объявило ракетами большой да...
# ...                                                 ...
# 4403  заместитель министра просвещения ирина карепин...
# 4404  глава штабов навального леонид волков призвал ...
# 4405  менеджеров стройки космодрома восточный взят с...
# 4406  морги луганской области переполнены телами пог...
# 4407  москве западные журналисты засняли депутатов г...
#
#                                            articleBody2
# 0     разница ожидать итог март нефтегазовый доход ф...
# 1     совет директор банк россия решать снижать ключ...
# 2     нато составлять наступательный план действие з...
# 3     президент владимир зеленский принимать полтава...
# 4     минобороны россия объявлять ракета большой дал...
# ...                                                 ...
# 4403  заместитель министр просвещение ирина карепин ...
# 4404  глава штаб навальный леонид волк призывать сво...
# 4405  менеджер стройка космодром восточный взять стр...
# 4406  морг луганский область переполнять тело погибш...
# 4407  москва западный журналист заснимать депутат го...
#
# [4408 rows x 8 columns]

# %%
# Объединения двух csv-файлов тестовой выборки в один файл
for i in tqdm(range(test_stances.shape[0])):
    for j in range(test_bodies.shape[0]):
        if train_bodies.loc[j,'Body ID']==train_stances.loc[i,'Body ID']:
            test_stances.loc[i,'articleBody'] = test_bodies.loc[j,'articleBody']
            test_stances.loc[i,'articleBody1'] = test_bodies.loc[j,'articleBody1']
            test_stances.loc[i,'articleBody2'] = test_bodies.loc[j,'articleBody2']
    test_stances.to_csv('data_test_combined.csv',index=False)
# Out:
#   0%|          | 0/1101 [00:00<?, ?it/s]

# %%
data_test = pd.read_csv('data_test_combined.csv') # Запишем новые данные в файд
data_test # Посмотрим на данные
# Out:
#       Body ID  label                                           Headline  \
# 0           1      0  ['лукашенко', 'пригрозил', 'литовским', 'танка...
# 1           2      1  ['российские', 'компании', 'оказались', 'опасн...
# 2           3      0  ['лукашенко', 'объявил', 'отмене', 'выборов', ...
# 3           4      1  ['«роснефть»', 'стала', 'лидером', 'объему', '...
# 4           5      1  ['псковской', 'области', 'дадут', 'десятки', '...
# ...       ...    ...                                                ...
# 1096     1097      0  ['борис', 'джонсон', 'пообещал', 'избирателям'...
# 1097     1098      0  ['михаил', 'горбачев', 'заявил', 'подавал', 'о...
# 1098     1099      0  ['мгимо', 'появится', 'факультет', 'международ...
# 1099     1100      0  ['россии', 'введут', 'штраф', 'отрицание', 'аг...
# 1100     1101      1  ['близкие', 'художницы', 'саши', 'скочиленко',...
#
#                                               Headline1  \
# 0     лукашенко пригрозил литовским танкам белорусск...
# 1     российские компании оказались в опасности из з...
# 2     лукашенко объявил об отмене выборов из за напа...
# 3     «роснефть» стала лидером по объему биржевых пр...
# 4     псковской области дадут десятки миллионов рубл...
# ...                                                 ...
# 1096  борис джонсон пообещал избирателям вернуть ирл...
# 1097  михаил горбачев заявил что не подавал в отстав...
# 1098  в мгимо появится факультет международных отнош...
# 1099  в россии введут штраф за отрицание агрессии нато
# 1100  близкие художницы саши скочиленко  арестованно...
#
#                                               Headline2  \
# 0     лукашенко пригрозить литовский танк белорусски...
# 1     российский компания оказываться опасность глоб...
# 2     лукашенко объявлять отмена выборы нападение ин...
# 3     роснефть становиться лидер объем биржевой прод...
# 4     псковский область давать десяток миллион рубль...
# ...                                                 ...
# 1096  борис джонсон пообещать избиратель вернуть ирл...
# 1097  михаил горбачев заявлять подавать отставка пос...
# 1098  мгимо появляться факультет международный отнош...
# 1099       россия вводить штраф отрицание агрессия нато
# 1100  близкий художница саша скочиленко арестовывать...
#
#                                             articleBody  \
# 0     Президент Беларуси Александр Лукашенко заявил,...
# 1     Несколько крупнейших российских компаний оказа...
# 2     Президент Белоруссии Александр Лукашенко объяв...
# 3     С начала июля нефтяные компании заметно увелич...
# 4     Псковская область получит 189 миллионов рублей...
# ...                                                 ...
# 1096  Кандидат в премьер-министры Великобритании Бор...
# 1097  Сенсационное заявление сделал 8 декабря в эфир...
# 1098  Московский государственный институт международ...
# 1099  На рассмотрение в Государственную думу поступи...
# 1100  Художница Саша Скочиленко, которую арестовали ...
#
#                                            articleBody1  \
# 0     президент беларуси александр лукашенко заявил ...
# 1     несколько крупнейших российских компаний оказа...
# 2     президент белоруссии александр лукашенко объяв...
# 3     начала июля нефтяные компании заметно увеличил...
# 4     псковская область получит 189 миллионов рублей...
# ...                                                 ...
# 1096  кандидат премьер министры великобритании борис...
# 1097  сенсационное заявление сделал 8 декабря эфире ...
# 1098  московский государственный институт международ...
# 1099  рассмотрение государственную думу поступил зак...
# 1100  художница саша скочиленко которую арестовали п...
#
#                                            articleBody2
# 0     президент беларусь александр лукашенко заявлят...
# 1     несколько крупный российский компания оказыват...
# 2     президент белоруссия александр лукашенко объяв...
# 3     начинать июль нефтяной компания заметно увелич...
# 4     псковский область получать миллион рубль ремон...
# ...                                                 ...
# 1096  кандидат премьер министр великобритания борис ...
# 1097  сенсационный заявление сделать декабрь эфир не...
# 1098  московский государственный институт международ...
# 1099  рассмотрение государственный дума поступать за...
# 1100  художница саша скочиленко который арестовывать...
#
# [1101 rows x 8 columns]

# %% [markdown]
# Данные тренировочной/тестовой выборки спарсены в один файл и готовы к последующей работе с ними.

# %% [markdown]
# # 1.2 Анализ данных

# %%
data.info() # Выведем информацию
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Body ID       4408 non-null   int64
#  1   Headline      4408 non-null   object
#  2   Stance        4408 non-null   object
#  3   Headline1     4408 non-null   object
#  4   Headline2     4408 non-null   object
#  5   articleBody   4408 non-null   object
#  6   articleBody1  4407 non-null   object
#  7   articleBody2  4407 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 275.6+ KB

# %%
data_test.info() # Выведем информацию
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Body ID       1101 non-null   int64
#  1   label         1101 non-null   int64
#  2   Headline      1101 non-null   object
#  3   Headline1     1101 non-null   object
#  4   Headline2     1101 non-null   object
#  5   articleBody   1101 non-null   object
#  6   articleBody1  1101 non-null   object
#  7   articleBody2  1101 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 68.9+ KB

# %% [markdown]
# Информация о данных в тренировочной/тестовой выборки:
# <li>4408/1101 записей</li>
# <li>7/7 колонок</li>
# <li>1/2 признака типа 'int64'</li>
# <li>7/6 признака тиа 'object'</li>
# <li>0/0 пропусков</li>

# %% [markdown]
# Обозначение признаков:
#
# <b>Unnamed: 0</b> - Номер строки
#
# <b>Body ID</b> - идентификатор id новости
#
# <b>Stance</b> - правдивость новости
#
# <b>Headline</b> - оригинальное название новостей
#
# <b>Headline1</b> - название новостей после чистки
#
# <b>Headline2</b> - название новостей после обработки модулем PyMystem3
#
# <b>articleBody</b> - оригинальное содержание новостей
#
# <b>articleBody1</b> -содержание новостей после чистки
#
# <b>articleBody2</b> - содержание новостей после обработки модулем PyMystem3

# %% [markdown]
# # 1.3 Обработка данных и подкачка словаря слов

# %%
# Кодируем котегориальную переменную
data['Stance'] = data['Stance'].replace(['agree', 'disagree'], [1, 0]).astype('int')

# %%
data # Посмотрим на датафрейм
# Out:
#       Body ID                                           Headline  Stance  \
# 0           1  ['российский', 'бюджет', 'марте', 'недополучил...       1
# 1           2  ['банк', 'россии', 'решил', 'снизить', 'ключев...       1
# 2           3  ['мыс', 'идокопас', 'нато', 'назвали', 'первую...       0
# 3           4  ['украине', 'прошли', 'празднования', '300', '...       0
# 4           5  ['минобороны', 'рф', 'заявило', 'ударах', 'рак...       1
# ...       ...                                                ...     ...
# 4403     4404  ['чиновница', 'призвавшая', '«найти', 'покарат...       0
# 4404     4405  ['«включим', 'программу', 'киселёва', 'покажем...       0
# 4405     4406  ['китайские', 'власти', 'могут', 'казнить', 'з...       0
# 4406     4407  ['луганской', 'области', 'переполнены', 'морги...       1
# 4407     4408  ['забывшему', 'удостоверение', 'депутату', 'го...       0
#
#                                               Headline1  \
# 0     российский бюджет в марте недополучил более 30...
# 1     банк россии решил снизить ключевую ставку с 20...
# 2     мыс идокопас  в нато назвали первую цель для н...
# 3     на украине прошли празднования 300 летия побед...
# 4     минобороны рф заявило об ударах ракетами «кали...
# ...                                                 ...
# 4403  чиновница призвавшая «найти и покарать предате...
# 4404  «включим программу киселёва и покажем телевизо...
# 4405  китайские власти могут казнить задержанного по...
# 4406  в луганской области переполнены морги  хранить...
# 4407  забывшему удостоверение депутату госдумы пришл...
#
#                                               Headline2  \
# 0     российский бюджет март недополучать миллиард р...
# 1            банк россия решать снижать ключевой ставка
# 2     мыс идокопас нато называть первый цель начало ...
# 3     украина проходить празднование летие победа ка...
# 4     минобороны заявлять удар ракета калибр запорож...
# ...                                                 ...
# 4403  чиновница призывать находить покарать предател...
# 4404  включать программа киселев показывать телевизо...
# 4405  китайский власть мочь казнить задержанный подо...
# 4406  луганский область переполнять морг хранить тел...
# 4407  забывать удостоверение депутат госдума приходи...
#
#                                             articleBody  \
# 0     Разница между ожидаемыми по итогам марта нефте...
# 1     Совет директоров Банка России решил снизить кл...
# 2     В НАТО составили наступательный план действий ...
# 3     Президент Владимир Зеленский принял в Полтаве ...
# 4     Минобороны России объявило, что ракетами больш...
# ...                                                 ...
# 4403  Заместитель министра просвещения Ирина Карепин...
# 4404  Глава штабов Навального Леонид Волков призвал ...
# 4405  Один из менеджеров стройки космодрома Восточны...
# 4406  Морги Луганской области переполнены телами пог...
# 4407  В Москве западные журналисты засняли, как один...
#
#                                            articleBody1  \
# 0     разница ожидаемыми итогам марта нефтегазовыми ...
# 1     совет директоров банка россии решил снизить кл...
# 2     нато составили наступательный план действий за...
# 3     президент владимир зеленский принял полтаве па...
# 4     минобороны россии объявило ракетами большой да...
# ...                                                 ...
# 4403  заместитель министра просвещения ирина карепин...
# 4404  глава штабов навального леонид волков призвал ...
# 4405  менеджеров стройки космодрома восточный взят с...
# 4406  морги луганской области переполнены телами пог...
# 4407  москве западные журналисты засняли депутатов г...
#
#                                            articleBody2
# 0     разница ожидать итог март нефтегазовый доход ф...
# 1     совет директор банк россия решать снижать ключ...
# 2     нато составлять наступательный план действие з...
# 3     президент владимир зеленский принимать полтава...
# 4     минобороны россия объявлять ракета большой дал...
# ...                                                 ...
# 4403  заместитель министр просвещение ирина карепин ...
# 4404  глава штаб навальный леонид волк призывать сво...
# 4405  менеджер стройка космодром восточный взять стр...
# 4406  морг луганский область переполнять тело погибш...
# 4407  москва западный журналист заснимать депутат го...
#
# [4408 rows x 8 columns]

# %%
# Сделаем столбец "Body ID" индексом
data = data.set_index("Body ID")
data
# Out:
#                                                   Headline  Stance  \
# Body ID
# 1        ['российский', 'бюджет', 'марте', 'недополучил...       1
# 2        ['банк', 'россии', 'решил', 'снизить', 'ключев...       1
# 3        ['мыс', 'идокопас', 'нато', 'назвали', 'первую...       0
# 4        ['украине', 'прошли', 'празднования', '300', '...       0
# 5        ['минобороны', 'рф', 'заявило', 'ударах', 'рак...       1
# ...                                                    ...     ...
# 4404     ['чиновница', 'призвавшая', '«найти', 'покарат...       0
# 4405     ['«включим', 'программу', 'киселёва', 'покажем...       0
# 4406     ['китайские', 'власти', 'могут', 'казнить', 'з...       0
# 4407     ['луганской', 'области', 'переполнены', 'морги...       1
# 4408     ['забывшему', 'удостоверение', 'депутату', 'го...       0
#
#                                                  Headline1  \
# Body ID
# 1        российский бюджет в марте недополучил более 30...
# 2        банк россии решил снизить ключевую ставку с 20...
# 3        мыс идокопас  в нато назвали первую цель для н...
# 4        на украине прошли празднования 300 летия побед...
# 5        минобороны рф заявило об ударах ракетами «кали...
# ...                                                    ...
# 4404     чиновница призвавшая «найти и покарать предате...
# 4405     «включим программу киселёва и покажем телевизо...
# 4406     китайские власти могут казнить задержанного по...
# 4407     в луганской области переполнены морги  хранить...
# 4408     забывшему удостоверение депутату госдумы пришл...
#
#                                                  Headline2  \
# Body ID
# 1        российский бюджет март недополучать миллиард р...
# 2               банк россия решать снижать ключевой ставка
# 3        мыс идокопас нато называть первый цель начало ...
# 4        украина проходить празднование летие победа ка...
# 5        минобороны заявлять удар ракета калибр запорож...
# ...                                                    ...
# 4404     чиновница призывать находить покарать предател...
# 4405     включать программа киселев показывать телевизо...
# 4406     китайский власть мочь казнить задержанный подо...
# 4407     луганский область переполнять морг хранить тел...
# 4408     забывать удостоверение депутат госдума приходи...
#
#                                                articleBody  \
# Body ID
# 1        Разница между ожидаемыми по итогам марта нефте...
# 2        Совет директоров Банка России решил снизить кл...
# 3        В НАТО составили наступательный план действий ...
# 4        Президент Владимир Зеленский принял в Полтаве ...
# 5        Минобороны России объявило, что ракетами больш...
# ...                                                    ...
# 4404     Заместитель министра просвещения Ирина Карепин...
# 4405     Глава штабов Навального Леонид Волков призвал ...
# 4406     Один из менеджеров стройки космодрома Восточны...
# 4407     Морги Луганской области переполнены телами пог...
# 4408     В Москве западные журналисты засняли, как один...
#
#                                               articleBody1  \
# Body ID
# 1        разница ожидаемыми итогам марта нефтегазовыми ...
# 2        совет директоров банка россии решил снизить кл...
# 3        нато составили наступательный план действий за...
# 4        президент владимир зеленский принял полтаве па...
# 5        минобороны россии объявило ракетами большой да...
# ...                                                    ...
# 4404     заместитель министра просвещения ирина карепин...
# 4405     глава штабов навального леонид волков призвал ...
# 4406     менеджеров стройки космодрома восточный взят с...
# 4407     морги луганской области переполнены телами пог...
# 4408     москве западные журналисты засняли депутатов г...
#
#                                               articleBody2
# Body ID
# 1        разница ожидать итог март нефтегазовый доход ф...
# 2        совет директор банк россия решать снижать ключ...
# 3        нато составлять наступательный план действие з...
# 4        президент владимир зеленский принимать полтава...
# 5        минобороны россия объявлять ракета большой дал...
# ...                                                    ...
# 4404     заместитель министр просвещение ирина карепин ...
# 4405     глава штаб навальный леонид волк призывать сво...
# 4406     менеджер стройка космодром восточный взять стр...
# 4407     морг луганский область переполнять тело погибш...
# 4408     москва западный журналист заснимать депутат го...
#
# [4408 rows x 7 columns]

# %%
# Распарсим столбец "Headline"
data['Headline'] = data['Headline'].apply(lambda x: "".join(x.replace("[", "").replace("]", "").replace("'", "").split(',')))
data
# Out:
#                                                   Headline  Stance  \
# Body ID
# 1        российский бюджет марте недополучил 300 миллиа...       1
# 2          банк россии решил снизить ключевую ставку 20 17       1
# 3        мыс идокопас нато назвали первую цель начала п...       0
# 4        украине прошли празднования 300 летия победы к...       0
# 5        минобороны рф заявило ударах ракетами «калибр»...       1
# ...                                                    ...     ...
# 4404     чиновница призвавшая «найти покарать предателе...       0
# 4405     «включим программу киселёва покажем телевизора...       0
# 4406     китайские власти могут казнить задержанного по...       0
# 4407     луганской области переполнены морги хранить те...       1
# 4408     забывшему удостоверение депутату госдумы пришл...       0
#
#                                                  Headline1  \
# Body ID
# 1        российский бюджет в марте недополучил более 30...
# 2        банк россии решил снизить ключевую ставку с 20...
# 3        мыс идокопас  в нато назвали первую цель для н...
# 4        на украине прошли празднования 300 летия побед...
# 5        минобороны рф заявило об ударах ракетами «кали...
# ...                                                    ...
# 4404     чиновница призвавшая «найти и покарать предате...
# 4405     «включим программу киселёва и покажем телевизо...
# 4406     китайские власти могут казнить задержанного по...
# 4407     в луганской области переполнены морги  хранить...
# 4408     забывшему удостоверение депутату госдумы пришл...
#
#                                                  Headline2  \
# Body ID
# 1        российский бюджет март недополучать миллиард р...
# 2               банк россия решать снижать ключевой ставка
# 3        мыс идокопас нато называть первый цель начало ...
# 4        украина проходить празднование летие победа ка...
# 5        минобороны заявлять удар ракета калибр запорож...
# ...                                                    ...
# 4404     чиновница призывать находить покарать предател...
# 4405     включать программа киселев показывать телевизо...
# 4406     китайский власть мочь казнить задержанный подо...
# 4407     луганский область переполнять морг хранить тел...
# 4408     забывать удостоверение депутат госдума приходи...
#
#                                                articleBody  \
# Body ID
# 1        Разница между ожидаемыми по итогам марта нефте...
# 2        Совет директоров Банка России решил снизить кл...
# 3        В НАТО составили наступательный план действий ...
# 4        Президент Владимир Зеленский принял в Полтаве ...
# 5        Минобороны России объявило, что ракетами больш...
# ...                                                    ...
# 4404     Заместитель министра просвещения Ирина Карепин...
# 4405     Глава штабов Навального Леонид Волков призвал ...
# 4406     Один из менеджеров стройки космодрома Восточны...
# 4407     Морги Луганской области переполнены телами пог...
# 4408     В Москве западные журналисты засняли, как один...
#
#                                               articleBody1  \
# Body ID
# 1        разница ожидаемыми итогам марта нефтегазовыми ...
# 2        совет директоров банка россии решил снизить кл...
# 3        нато составили наступательный план действий за...
# 4        президент владимир зеленский принял полтаве па...
# 5        минобороны россии объявило ракетами большой да...
# ...                                                    ...
# 4404     заместитель министра просвещения ирина карепин...
# 4405     глава штабов навального леонид волков призвал ...
# 4406     менеджеров стройки космодрома восточный взят с...
# 4407     морги луганской области переполнены телами пог...
# 4408     москве западные журналисты засняли депутатов г...
#
#                                               articleBody2
# Body ID
# 1        разница ожидать итог март нефтегазовый доход ф...
# 2        совет директор банк россия решать снижать ключ...
# 3        нато составлять наступательный план действие з...
# 4        президент владимир зеленский принимать полтава...
# 5        минобороны россия объявлять ракета большой дал...
# ...                                                    ...
# 4404     заместитель министр просвещение ирина карепин ...
# 4405     глава штаб навальный леонид волк призывать сво...
# 4406     менеджер стройка космодром восточный взять стр...
# 4407     морг луганский область переполнять тело погибш...
# 4408     москва западный журналист заснимать депутат го...
#
# [4408 rows x 7 columns]

# %%
data_test['Stance'] = data_test['label'] # Переименуем целевую метрику
data_test.drop('label', axis=1, inplace=True)
data_test
# Out:
#       Body ID                                           Headline  \
# 0           1  ['лукашенко', 'пригрозил', 'литовским', 'танка...
# 1           2  ['российские', 'компании', 'оказались', 'опасн...
# 2           3  ['лукашенко', 'объявил', 'отмене', 'выборов', ...
# 3           4  ['«роснефть»', 'стала', 'лидером', 'объему', '...
# 4           5  ['псковской', 'области', 'дадут', 'десятки', '...
# ...       ...                                                ...
# 1096     1097  ['борис', 'джонсон', 'пообещал', 'избирателям'...
# 1097     1098  ['михаил', 'горбачев', 'заявил', 'подавал', 'о...
# 1098     1099  ['мгимо', 'появится', 'факультет', 'международ...
# 1099     1100  ['россии', 'введут', 'штраф', 'отрицание', 'аг...
# 1100     1101  ['близкие', 'художницы', 'саши', 'скочиленко',...
#
#                                               Headline1  \
# 0     лукашенко пригрозил литовским танкам белорусск...
# 1     российские компании оказались в опасности из з...
# 2     лукашенко объявил об отмене выборов из за напа...
# 3     «роснефть» стала лидером по объему биржевых пр...
# 4     псковской области дадут десятки миллионов рубл...
# ...                                                 ...
# 1096  борис джонсон пообещал избирателям вернуть ирл...
# 1097  михаил горбачев заявил что не подавал в отстав...
# 1098  в мгимо появится факультет международных отнош...
# 1099  в россии введут штраф за отрицание агрессии нато
# 1100  близкие художницы саши скочиленко  арестованно...
#
#                                               Headline2  \
# 0     лукашенко пригрозить литовский танк белорусски...
# 1     российский компания оказываться опасность глоб...
# 2     лукашенко объявлять отмена выборы нападение ин...
# 3     роснефть становиться лидер объем биржевой прод...
# 4     псковский область давать десяток миллион рубль...
# ...                                                 ...
# 1096  борис джонсон пообещать избиратель вернуть ирл...
# 1097  михаил горбачев заявлять подавать отставка пос...
# 1098  мгимо появляться факультет международный отнош...
# 1099       россия вводить штраф отрицание агрессия нато
# 1100  близкий художница саша скочиленко арестовывать...
#
#                                             articleBody  \
# 0     Президент Беларуси Александр Лукашенко заявил,...
# 1     Несколько крупнейших российских компаний оказа...
# 2     Президент Белоруссии Александр Лукашенко объяв...
# 3     С начала июля нефтяные компании заметно увелич...
# 4     Псковская область получит 189 миллионов рублей...
# ...                                                 ...
# 1096  Кандидат в премьер-министры Великобритании Бор...
# 1097  Сенсационное заявление сделал 8 декабря в эфир...
# 1098  Московский государственный институт международ...
# 1099  На рассмотрение в Государственную думу поступи...
# 1100  Художница Саша Скочиленко, которую арестовали ...
#
#                                            articleBody1  \
# 0     президент беларуси александр лукашенко заявил ...
# 1     несколько крупнейших российских компаний оказа...
# 2     президент белоруссии александр лукашенко объяв...
# 3     начала июля нефтяные компании заметно увеличил...
# 4     псковская область получит 189 миллионов рублей...
# ...                                                 ...
# 1096  кандидат премьер министры великобритании борис...
# 1097  сенсационное заявление сделал 8 декабря эфире ...
# 1098  московский государственный институт международ...
# 1099  рассмотрение государственную думу поступил зак...
# 1100  художница саша скочиленко которую арестовали п...
#
#                                            articleBody2  Stance
# 0     президент беларусь александр лукашенко заявлят...       0
# 1     несколько крупный российский компания оказыват...       1
# 2     президент белоруссия александр лукашенко объяв...       0
# 3     начинать июль нефтяной компания заметно увелич...       1
# 4     псковский область получать миллион рубль ремон...       1
# ...                                                 ...     ...
# 1096  кандидат премьер министр великобритания борис ...       0
# 1097  сенсационный заявление сделать декабрь эфир не...       0
# 1098  московский государственный институт международ...       0
# 1099  рассмотрение государственный дума поступать за...       0
# 1100  художница саша скочиленко который арестовывать...       1
#
# [1101 rows x 8 columns]

# %%
# Сделаем столбец "Body ID" индексом
data_test = data_test.set_index("Body ID")
data_test
# Out:
#                                                   Headline  \
# Body ID
# 1        ['лукашенко', 'пригрозил', 'литовским', 'танка...
# 2        ['российские', 'компании', 'оказались', 'опасн...
# 3        ['лукашенко', 'объявил', 'отмене', 'выборов', ...
# 4        ['«роснефть»', 'стала', 'лидером', 'объему', '...
# 5        ['псковской', 'области', 'дадут', 'десятки', '...
# ...                                                    ...
# 1097     ['борис', 'джонсон', 'пообещал', 'избирателям'...
# 1098     ['михаил', 'горбачев', 'заявил', 'подавал', 'о...
# 1099     ['мгимо', 'появится', 'факультет', 'международ...
# 1100     ['россии', 'введут', 'штраф', 'отрицание', 'аг...
# 1101     ['близкие', 'художницы', 'саши', 'скочиленко',...
#
#                                                  Headline1  \
# Body ID
# 1        лукашенко пригрозил литовским танкам белорусск...
# 2        российские компании оказались в опасности из з...
# 3        лукашенко объявил об отмене выборов из за напа...
# 4        «роснефть» стала лидером по объему биржевых пр...
# 5        псковской области дадут десятки миллионов рубл...
# ...                                                    ...
# 1097     борис джонсон пообещал избирателям вернуть ирл...
# 1098     михаил горбачев заявил что не подавал в отстав...
# 1099     в мгимо появится факультет международных отнош...
# 1100     в россии введут штраф за отрицание агрессии нато
# 1101     близкие художницы саши скочиленко  арестованно...
#
#                                                  Headline2  \
# Body ID
# 1        лукашенко пригрозить литовский танк белорусски...
# 2        российский компания оказываться опасность глоб...
# 3        лукашенко объявлять отмена выборы нападение ин...
# 4        роснефть становиться лидер объем биржевой прод...
# 5        псковский область давать десяток миллион рубль...
# ...                                                    ...
# 1097     борис джонсон пообещать избиратель вернуть ирл...
# 1098     михаил горбачев заявлять подавать отставка пос...
# 1099     мгимо появляться факультет международный отнош...
# 1100          россия вводить штраф отрицание агрессия нато
# 1101     близкий художница саша скочиленко арестовывать...
#
#                                                articleBody  \
# Body ID
# 1        Президент Беларуси Александр Лукашенко заявил,...
# 2        Несколько крупнейших российских компаний оказа...
# 3        Президент Белоруссии Александр Лукашенко объяв...
# 4        С начала июля нефтяные компании заметно увелич...
# 5        Псковская область получит 189 миллионов рублей...
# ...                                                    ...
# 1097     Кандидат в премьер-министры Великобритании Бор...
# 1098     Сенсационное заявление сделал 8 декабря в эфир...
# 1099     Московский государственный институт международ...
# 1100     На рассмотрение в Государственную думу поступи...
# 1101     Художница Саша Скочиленко, которую арестовали ...
#
#                                               articleBody1  \
# Body ID
# 1        президент беларуси александр лукашенко заявил ...
# 2        несколько крупнейших российских компаний оказа...
# 3        президент белоруссии александр лукашенко объяв...
# 4        начала июля нефтяные компании заметно увеличил...
# 5        псковская область получит 189 миллионов рублей...
# ...                                                    ...
# 1097     кандидат премьер министры великобритании борис...
# 1098     сенсационное заявление сделал 8 декабря эфире ...
# 1099     московский государственный институт международ...
# 1100     рассмотрение государственную думу поступил зак...
# 1101     художница саша скочиленко которую арестовали п...
#
#                                               articleBody2  Stance
# Body ID
# 1        президент беларусь александр лукашенко заявлят...       0
# 2        несколько крупный российский компания оказыват...       1
# 3        президент белоруссия александр лукашенко объяв...       0
# 4        начинать июль нефтяной компания заметно увелич...       1
# 5        псковский область получать миллион рубль ремон...       1
# ...                                                    ...     ...
# 1097     кандидат премьер министр великобритания борис ...       0
# 1098     сенсационный заявление сделать декабрь эфир не...       0
# 1099     московский государственный институт международ...       0
# 1100     рассмотрение государственный дума поступать за...       0
# 1101     художница саша скочиленко который арестовывать...       1
#
# [1101 rows x 7 columns]

# %%
# Распарсим столбец "Headline"
data_test['Headline'] = data_test['Headline'].apply(lambda x: "".join(x.replace("[", "").replace("]", "").replace("'", "").split(',')))
data_test
# Out:
#                                                   Headline  \
# Body ID
# 1        лукашенко пригрозил литовским танкам белорусск...
# 2        российские компании оказались опасности глобал...
# 3        лукашенко объявил отмене выборов нападения ино...
# 4        «роснефть» стала лидером объему биржевых прода...
# 5        псковской области дадут десятки миллионов рубл...
# ...                                                    ...
# 1097     борис джонсон пообещал избирателям вернуть ирл...
# 1098     михаил горбачев заявил подавал отставку поста ...
# 1099     мгимо появится факультет международных отношен...
# 1100           россии введут штраф отрицание агрессии нато
# 1101     близкие художницы саши скочиленко арестованной...
#
#                                                  Headline1  \
# Body ID
# 1        лукашенко пригрозил литовским танкам белорусск...
# 2        российские компании оказались в опасности из з...
# 3        лукашенко объявил об отмене выборов из за напа...
# 4        «роснефть» стала лидером по объему биржевых пр...
# 5        псковской области дадут десятки миллионов рубл...
# ...                                                    ...
# 1097     борис джонсон пообещал избирателям вернуть ирл...
# 1098     михаил горбачев заявил что не подавал в отстав...
# 1099     в мгимо появится факультет международных отнош...
# 1100     в россии введут штраф за отрицание агрессии нато
# 1101     близкие художницы саши скочиленко  арестованно...
#
#                                                  Headline2  \
# Body ID
# 1        лукашенко пригрозить литовский танк белорусски...
# 2        российский компания оказываться опасность глоб...
# 3        лукашенко объявлять отмена выборы нападение ин...
# 4        роснефть становиться лидер объем биржевой прод...
# 5        псковский область давать десяток миллион рубль...
# ...                                                    ...
# 1097     борис джонсон пообещать избиратель вернуть ирл...
# 1098     михаил горбачев заявлять подавать отставка пос...
# 1099     мгимо появляться факультет международный отнош...
# 1100          россия вводить штраф отрицание агрессия нато
# 1101     близкий художница саша скочиленко арестовывать...
#
#                                                articleBody  \
# Body ID
# 1        Президент Беларуси Александр Лукашенко заявил,...
# 2        Несколько крупнейших российских компаний оказа...
# 3        Президент Белоруссии Александр Лукашенко объяв...
# 4        С начала июля нефтяные компании заметно увелич...
# 5        Псковская область получит 189 миллионов рублей...
# ...                                                    ...
# 1097     Кандидат в премьер-министры Великобритании Бор...
# 1098     Сенсационное заявление сделал 8 декабря в эфир...
# 1099     Московский государственный институт международ...
# 1100     На рассмотрение в Государственную думу поступи...
# 1101     Художница Саша Скочиленко, которую арестовали ...
#
#                                               articleBody1  \
# Body ID
# 1        президент беларуси александр лукашенко заявил ...
# 2        несколько крупнейших российских компаний оказа...
# 3        президент белоруссии александр лукашенко объяв...
# 4        начала июля нефтяные компании заметно увеличил...
# 5        псковская область получит 189 миллионов рублей...
# ...                                                    ...
# 1097     кандидат премьер министры великобритании борис...
# 1098     сенсационное заявление сделал 8 декабря эфире ...
# 1099     московский государственный институт международ...
# 1100     рассмотрение государственную думу поступил зак...
# 1101     художница саша скочиленко которую арестовали п...
#
#                                               articleBody2  Stance
# Body ID
# 1        президент беларусь александр лукашенко заявлят...       0
# 2        несколько крупный российский компания оказыват...       1
# 3        президент белоруссия александр лукашенко объяв...       0
# 4        начинать июль нефтяной компания заметно увелич...       1
# 5        псковский область получать миллион рубль ремон...       1
# ...                                                    ...     ...
# 1097     кандидат премьер министр великобритания борис ...       0
# 1098     сенсационный заявление сделать декабрь эфир не...       0
# 1099     московский государственный институт международ...       0
# 1100     рассмотрение государственный дума поступать за...       0
# 1101     художница саша скочиленко который арестовывать...       1
#
# [1101 rows x 7 columns]

# %%
# Подкачка словаря слов
nltk.download("stopwords")
russian_stopwords = stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\k1rsn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Данные готовы для передачи в модели

# %% [markdown]
# # 2.1 Обучение моделей "из коробки"

# %%
def fit_predict_score_model(df, model, df_test):
    """
    Input:
        df - тренировочный датафрейм с заголовком и текстом новости
        model - модель машинного обучения
        df_test - тестовый датафрейм с заголовком и текстом новости
    Return:
        Первым параметром возвращаем точность классификации модели на заголовках новостей
        Вторым параметром возвращаем точность классификации модели на содержании новостей
    """
    vectorizer = CountVectorizer(max_features=1500, min_df=5, max_df=0.7, stop_words=russian_stopwords)
    columns = df.drop('Stance', axis=1).columns # Получаем список признаков
    print("-"*30)
    print(f"   Пара признаков: {columns[0]} и {columns[1]}")
    
    # Обучаем CountVectorizer на всех новостях
    vectorizer.fit(df[columns[0]].values.astype('U'))
    vectorizer.fit(df[columns[1]].values.astype('U'))
    vectorizer.fit(df_test[columns[0]].values.astype('U'))
    vectorizer.fit(df_test[columns[1]].values.astype('U'))

    # Трансформируем текст в массив id-шников слов
    X11 = vectorizer.transform(df[columns[0]].values.astype('U')).toarray()
    X12 = vectorizer.transform(df[columns[1]].values.astype('U')).toarray()
    X21 = vectorizer.transform(df_test[columns[0]].values.astype('U')).toarray()
    X22 = vectorizer.transform(df_test[columns[1]].values.astype('U')).toarray()

    # Обучаем модель на заголовках новостей и смотрим на точность 
    print('   Обучение на заголовках')
    model_new = model
    model_new.fit(X11, df.Stance)
    preds1 = model_new.predict(X21)
    print(f"      Точность на заголовках: {accuracy_score(df_test.Stance, preds1)}")

    # Обучаем модель на содержание новостей и смотрим на точность 
    print('   Обучение на содержание')
    model_new = model
    model_new.fit(X12, df.Stance)
    preds2 = model_new.predict(X22)
    print(f"      Точность на содержаниях: {accuracy_score(df_test.Stance, preds2)}")
    
    return accuracy_score(df_test.Stance, preds1), accuracy_score(df_test.Stance, preds2)

# %%
# Формируем DataFrame для записей точности моделей
accuracy_df = pd.DataFrame(columns=['Name Model', 'Headline', 'articleBody', 'Headline1', 'articleBody1', 'Headline2', 'articleBody2'])

i = 0
for model in [LogisticRegression(), RandomForestClassifier(), DecisionTreeClassifier(), SVC()]: 
    # Словарь для заполнения в DataFrame точностей по модели
    accuracy_list = {'Name Model':None, 'Headline':None, 'articleBody':None, 'Headline1':None, 'articleBody1':None, 
                     'Headline2':None, 'articleBody2':None}
    print("*"*30)
    print(model.__class__.__name__)
    print("*"*30)

    # Тренируем модель на оригинальных данных и записываем в словарь
    itog1, itog2 = fit_predict_score_model(data[['Headline', 'articleBody', 'Stance']], model, data_test[['Headline', 'articleBody', 'Stance']])
    accuracy_list['Name Model'] = model.__class__.__name__
    accuracy_list['Headline'] = itog1
    accuracy_list['articleBody'] = itog2

    # Тренируем модель на данных после чистки и записываем в словарь
    itog1, itog2 = fit_predict_score_model(data[['Headline1', 'articleBody1', 'Stance']], model, data_test[['Headline1', 'articleBody1', 'Stance']])
    accuracy_list['Headline1'] = itog1
    accuracy_list['articleBody1'] = itog2
    
    # Тренируем модель на данных после обработки модулем PyMystem3 и записываем в словарь
    itog1, itog2 = fit_predict_score_model(data[['Headline2', 'articleBody2', 'Stance']], model, data_test[['Headline2', 'articleBody2', 'Stance']])
    accuracy_list['Headline2'] = itog1
    accuracy_list['articleBody2'] = itog2

    # Записываем данные по модели в датафрейм
    accuracy_df = pd.concat([accuracy_df, pd.DataFrame(accuracy_list, index=[i])], ignore_index=True)
    i += 1
# Out:
# ******************************
# LogisticRegression
# ******************************
# ------------------------------
#    Пара признаков: Headline и articleBody
#    Обучение на заголовках
#       Точность на заголовках: 0.740236148955495
#    Обучение на содержание
#       Точность на содержаниях: 0.9346049046321526
# ------------------------------
#    Пара признаков: Headline1 и articleBody1
#    Обучение на заголовках
#       Точность на заголовках: 0.737511353315168
#    Обучение на содержание
#       Точность на содержаниях: 0.9346049046321526
# ------------------------------
#    Пара признаков: Headline2 и articleBody2
#    Обучение на заголовках
#       Точность на заголовках: 0.7938237965485921
#    Обучение на содержание
#       Точность на содержаниях: 0.932788374205268
# ******************************
# RandomForestClassifier
# ******************************
# ------------------------------
#    Пара признаков: Headline и articleBody
#    Обучение на заголовках
#       Точность на заголовках: 0.742960944595822
#    Обучение на содержание
#       Точность на содержаниях: 0.9173478655767484
# ------------------------------
#    Пара признаков: Headline1 и articleBody1
#    Обучение на заголовках
#       Точность на заголовках: 0.7366030881017257
#    Обучение на содержание
#       Точность на содержаниях: 0.9209809264305178
# ------------------------------
#    Пара признаков: Headline2 и articleBody2
#    Обучение на заголовках
#       Точность на заголовках: 0.7892824704813806
#    Обучение на содержание
#       Точность на содержаниях: 0.9264305177111717
# ******************************
# DecisionTreeClassifier
# ******************************
# ------------------------------
#    Пара признаков: Headline и articleBody
#    Обучение на заголовках
#       Точность на заголовках: 0.6875567665758402
#    Обучение на содержание
#       Точность на содержаниях: 0.8247048138056312
# ------------------------------
#    Пара признаков: Headline1 и articleBody1
#    Обучение на заголовках
#       Точность на заголовках: 0.6830154405086285
#    Обучение на содержание
#       Точность на содержаниях: 0.8319709355131698
# ------------------------------
#    Пара признаков: Headline2 и articleBody2
#    Обучение на заголовках
#       Точность на заголовках: 0.7257039055404177
#    Обучение на содержание
#       Точность на содержаниях: 0.8219800181653043
# ******************************
# SVC
# ******************************
# ------------------------------
#    Пара признаков: Headline и articleBody
#    Обучение на заголовках
#       Точность на заголовках: 0.7520435967302452
#    Обучение на содержание
#       Точность на содержаниях: 0.9445958219800181
# ------------------------------
#    Пара признаков: Headline1 и articleBody1
#    Обучение на заголовках
#       Точность на заголовках: 0.7520435967302452
#    Обучение на содержание
#       Точность на содержаниях: 0.9445958219800181
# ------------------------------
#    Пара признаков: Headline2 и articleBody2
#    Обучение на заголовках
#       Точность на заголовках: 0.8065395095367848
#    Обучение на содержание
#       Точность на содержаниях: 0.9373297002724795

# %% [markdown]
# Информация по точности всех моделей "из коробки" для каждых типов данных новостей получены

# %% [markdown]
# # 2.2 Выявление модели с лучшей точностью

# %%
accuracy_df = accuracy_df.set_index('Name Model') # Меняем индексы на название моделей

# %%
accuracy_df # Смотрим на данные
# Out:
#                         Headline  articleBody  Headline1  articleBody1  \
# Name Model
# LogisticRegression      0.740236     0.934605   0.737511      0.934605
# RandomForestClassifier  0.742961     0.917348   0.736603      0.920981
# DecisionTreeClassifier  0.687557     0.824705   0.683015      0.831971
# SVC                     0.752044     0.944596   0.752044      0.944596
#
#                         Headline2  articleBody2
# Name Model
# LogisticRegression       0.793824      0.932788
# RandomForestClassifier   0.789282      0.926431
# DecisionTreeClassifier   0.725704      0.821980
# SVC                      0.806540      0.937330

# %%
# Сравниваем среднюю точность модели по каждому из признаков
round(accuracy_df.mean().sort_values(ascending=0), 3)
# Out:
# articleBody1    0.908
# articleBody     0.905
# articleBody2    0.905
# Headline2       0.779
# Headline        0.731
# Headline1       0.727
# dtype: float64

# %% [markdown]
# Можно увидеть, что оригинальное содержание новостей после чистки даёт больше всего информативности, что помогает более точно классифицировать достоверность

# %%
# Сравниваем точность модели по более информативному признаку
round(accuracy_df['articleBody1'].sort_values(ascending=0)*100, 3)
# Out:
# Name Model
# SVC                       94.460
# LogisticRegression        93.460
# RandomForestClassifier    92.098
# DecisionTreeClassifier    83.197
# Name: articleBody1, dtype: float64

# %% [markdown]
# Лучший показатель точности "из коробки" показала модель SVC. Именно её будет лучше обучать

# %% [markdown]
# # 2.3 Обучение гиперпараметров у лучшей модели

# %%
# Гиперпараметры для обучения
param_grid = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

# Инициализируем модель с автоподбором гиперпараметров
clf = GridSearchCV(estimator=SVC(), param_grid=param_grid, cv=3,  n_jobs=-1)

# %%
# Предобрабатываем данные для модели
vectorizer = CountVectorizer(max_features=1500, min_df=5, max_df=0.7, stop_words=russian_stopwords)
vectorizer.fit(data['articleBody1'].values.astype('U'))         
vectorizer.fit(data_test['articleBody1'].values.astype('U'))   
X_train = vectorizer.transform(data['articleBody1'].values.astype('U')).toarray()         
X_test = vectorizer.transform(data_test['articleBody1'].values.astype('U')).toarray()

# %%
# %%time
clf.fit(X_train, data.Stance) # Обучаем все возможные модели 
svc_best = clf.best_estimator_ # Получаем лучший экземпляр
svc_best.fit(X_train, data.Stance) # Обучаем лучший экземляр
preds = svc_best.predict(X_test) # Предсказываем
print(f"Точность на тесте: {round(accuracy_score(data_test.Stance, preds), 3)}")
# Out:
# Точность на тесте: 0.95
# CPU times: total: 9 s
# Wall time: 1min 37s

# %% [markdown]
# Как итог, мы смогли поднять точность на 0.54% и добиться точности в 95%, что является отличным результатом
